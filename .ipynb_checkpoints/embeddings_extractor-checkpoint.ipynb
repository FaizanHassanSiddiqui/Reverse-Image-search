# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import os
import time

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
import json

# %%
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16

# %%
def load_image_data(folder, file_index = {} ):
    
    if not file_index:
        names = [fold for fold in os.listdir(folder) if ".DS" not in fold]
        
    else:
        names = [fold for fold in os.listdir(folder) if ".DS" not in fold]
        names = list(set(names) - set(file_index.values()))
    
    image_list = []
    images_names = []
    
    


    for name in names:
        full_path = os.path.join(folder, name)
        try:
            img = image.load_img(full_path, target_size=(224, 224))
            images_names.append(name)
        except:
            
            continue
            
        x_raw = image.img_to_array(img)
        x_expand = np.expand_dims(x_raw, axis=0)
        x = preprocess_input(x_expand)
        image_list.append(x)
        
        
    img_data = np.array(image_list)
    img_data = np.rollaxis(img_data, 1, 0)
    img_data = img_data[0]

    return img_data, images_names

# %%
try:    
    with open('file_index.json') as f_in:
        file_index = json.load(f_in)
        
except:
    file_index = {}

# %%
new_images,  new_images_names = load_image_data('images_base', file_index )

# %%
new_images.shape
# Out:
# (908, 224, 224, 3)

# %%
len(new_images_names)
# Out:
# 908

# %%
pretrained_vgg16 = VGG16(weights='imagenet', include_top=True)
model = Model(inputs=pretrained_vgg16.input,
                  outputs=pretrained_vgg16.get_layer('fc2').output)

# %%
def generate_features(images_names, model, file_index, previous_feature_array):
    """
    Takes in an array of image paths, and a trained model.
    Returns the activations of the last layer for each image
    :param images_names: array of image names
    :param model: pre-trained model
    :return: array of last-layer activations, and mapping from array_index to file_path
    """
    start = time.time()
    
    
    images = np.zeros(shape=(len(images_names), 224, 224, 3))
    
    file_index_length = len(file_index)
    
    folder = 'images_base'
    
    for i, f in enumerate(images_names):
        
        file_index[i + file_index_length] = f
            
        full_path = os.path.join(folder, f)
        img = image.load_img(full_path, target_size=(224, 224))
        x_raw = image.img_to_array(img)
        x_expand = np.expand_dims(x_raw, axis=0)
        images[i, :, :, :] = x_expand

    
    inputs = preprocess_input(images)
    
    if previous_feature_array == None:
        images_features = model.predict(inputs)
    else:
        new_images_features = model.predict(inputs)
        images_features = np.vstack(previous_feature_array, new_images_features)
    
    end = time.time()
    print("Inference done, %s Generation time" % (end - start))
    return images_features, file_index

# %%
try:
    previous_images_features = np.load('image_features.npy')
except:
    previous_images_features = None

# %%
all_images_features, latest_file_index = generate_features(new_images_names, model, file_index, previous_images_features)
# Out:
# Inference done, 463.86906695365906 Generation time

# %%
np.save('image_features', all_images_features)

with open('file_index.json', 'w') as fp:
    json.dump(latest_file_index, fp)

# %%
all_images_features.shape
# Out:
# (908, 4096)

# %%
latest_file_index
# Out:
# {0: '100_jumia.jpg',
#  1: '101_jumia.jpg',
#  2: '102_jumia.jpg',
#  3: '103_ebay.jpg',
#  4: '104_ebay.jpg',
#  5: '105_ebay.jpg',
#  6: '106_ebay.jpg',
#  7: '107_ebay.jpg',
#  8: '108_ebay.jpg',
#  9: '109_ebay.jpg',
#  10: '10_olist.jpg',
#  11: '110_ebay.jpg',
#  12: '111_ebay.jpg',
#  13: '112_ebay.jpg',
#  14: '113_ebay.jpg',
#  15: '114_ebay.jpg',
#  16: '115_ebay.jpg',
#  17: '116_ebay.jpg',
#  18: '117_ebay.jpg',
#  19: '118_ebay.jpg',
#  20: '119_ebay.jpg',
#  21: '11_olist.jpg',
#  22: '120_ebay.jpg',
#  23: '121_ebay.jpg',
#  24: '122_ebay.jpg',
#  25: '123_ebay.jpg',
#  26: '124_ebay.jpg',
#  27: '125_ebay.jpg',
#  28: '126_ebay.jpg',
#  29: '127_ebay.jpg',
#  30: '128_ebay.jpg',
#  31: '129_ebay.jpg',
#  32: '12_olist.jpg',
#  33: '130_ebay.jpg',
#  34: '131_ebay.jpg',
#  35: '132_ebay.jpg',
#  36: '133_ebay.jpg',
#  37: '134_ebay.jpg',
#  38: '135_ebay.jpg',
#  39: '136_ebay.jpg',
#  40: '137_ebay.jpg',
#  41: '138_ebay.jpg',
#  42: '139_ebay.jpg',
#  43: '13_olist.jpg',
#  44: '140_ebay.jpg',
#  45: '141_ebay.jpg',
#  46: '142_ebay.jpg',
#  47: '143_ebay.jpg',
#  48: '144_ebay.jpg',
#  49: '145_ebay.jpg',
#  50: '146_ebay.jpg',
#  51: '147_ebay.jpg',
#  52: '148_ebay.jpg',
#  53: '149_ebay.jpg',
#  54: '14_olist.jpg',
#  55: '150_ebay.jpg',
#  56: '151_ebay.jpg',
#  57: '152_ebay.jpg',
#  58: '153_ebay.jpg',
#  59: '154_ebay.jpg',
#  60: '155_ebay.jpg',
#  61: '156_ebay.jpg',
#  62: '157_ebay.jpg',
#  63: '158_ebay.jpg',
#  64: '159_ebay.jpg',
#  65: '160_ebay.jpg',
#  66: '161_ebay.jpg',
#  67: '162_ebay.jpg',
#  68: '163_ebay.jpg',
#  69: '164_ebay.jpg',
#  70: '165_ebay.jpg',
#  71: '166_ebay.jpg',
#  72: '167_ebay.jpg',
#  73: '168_ebay.jpg',
#  74: '169_ebay.jpg',
#  75: '16_olist.jpg',
#  76: '170_ebay.jpg',
#  77: '171_ebay.jpg',
#  78: '172_ebay.jpg',
#  79: '173_ebay.jpg',
#  80: '174_ebay.jpg',
#  81: '175_ebay.jpg',
#  82: '176_ebay.jpg',
#  83: '177_ebay.jpg',
#  84: '178_ebay.jpg',
#  85: '179_ebay.jpg',
#  86: '180_ebay.jpg',
#  87: '181_ebay.jpg',
#  88: '182_ebay.jpg',
#  89: '183_ebay.jpg',
#  90: '184_ebay.jpg',
#  91: '185_ebay.jpg',
#  92: '186_ebay.jpg',
#  93: '187_ebay.jpg',
#  94: '188_ebay.jpg',
#  95: '189_ebay.jpg',
#  96: '190_ebay.jpg',
#  97: '191_ebay.jpg',
#  98: '192_ebay.jpg',
#  99: '193_ebay.jpg',
#  100: '194_ebay.jpg',
#  101: '195_ebay.jpg',
#  102: '196_ebay.jpg',
#  103: '197_ebay.jpg',
#  104: '198_ebay.jpg',
#  105: '199_ebay.jpg',
#  106: '19_olist.jpg',
#  107: '200_ebay.jpg',
#  108: '201_ebay.jpg',
#  109: '202_ebay.jpg',
#  110: '203_ebay.jpg',
#  111: '204_ebay.jpg',
#  112: '205_ebay.jpg',
#  113: '206_ebay.jpg',
#  114: '207_ebay.jpg',
#  115: '208_ebay.jpg',
#  116: '209_ebay.jpg',
#  117: '20_olist.jpg',
#  118: '210_ebay.jpg',
#  119: '211_ebay.jpg',
#  120: '212_ebay.jpg',
#  121: '213_ebay.jpg',
#  122: '214_ebay.jpg',
#  123: '215_ebay.jpg',
#  124: '216_ebay.jpg',
#  125: '217_ebay.jpg',
#  126: '218_ebay.jpg',
#  127: '219_ebay.jpg',
#  128: '220_ebay.jpg',
#  129: '221_ebay.jpg',
#  130: '222_ebay.jpg',
#  131: '223_ebay.jpg',
#  132: '224_ebay.jpg',
#  133: '225_ebay.jpg',
#  134: '226_ebay.jpg',
#  135: '227_ebay.jpg',
#  136: '228_ebay.jpg',
#  137: '229_ebay.jpg',
#  138: '22_olist.jpg',
#  139: '230_ebay.jpg',
#  140: '231_ebay.jpg',
#  141: '232_ebay.jpg',
#  142: '233_ebay.jpg',
#  143: '234_ebay.jpg',
#  144: '235_ebay.jpg',
#  145: '236_ebay.jpg',
#  146: '237_ebay.jpg',
#  147: '238_ebay.jpg',
#  148: '249_cars45.jpg',
#  149: '250_cars45.jpg',
#  150: '251_cars45.jpg',
#  151: '252_cars45.jpg',
#  152: '254_cars45.jpg',
#  153: '257_cars45.jpg',
#  154: '259_cars45.jpg',
#  155: '25_olist.jpg',
#  156: '268_cars45.jpg',
#  157: '269_cars45.jpg',
#  158: '26_olist.jpg',
#  159: '270_cars45.jpg',
#  160: '273_cars45.jpg',
#  161: '274_cars45.jpg',
#  162: '280_cars45.jpg',
#  163: '283_cars45.jpg',
#  164: '287_cars45.jpg',
#  165: '288_cars45.jpg',
#  166: '28_olist.jpg',
#  167: '294_jumia.jpg',
#  168: '295_jumia.jpg',
#  169: '296_jumia.jpg',
#  170: '297_jumia.jpg',
#  171: '298_jumia.jpg',
#  172: '299_jumia.jpg',
#  173: '2_olist.jpg',
#  174: '300_jumia.jpg',
#  175: '301_jumia.jpg',
#  176: '302_jumia.jpg',
#  177: '303_jumia.jpg',
#  178: '304_jumia.jpg',
#  179: '305_jumia.jpg',
#  180: '306_jumia.jpg',
#  181: '307_jumia.jpg',
#  182: '308_jumia.jpg',
#  183: '309_jumia.jpg',
#  184: '30_olist.jpg',
#  185: '310_jumia.jpg',
#  186: '311_jumia.jpg',
#  187: '312_jumia.jpg',
#  188: '313_jumia.jpg',
#  189: '314_jumia.jpg',
#  190: '315_jumia.jpg',
#  191: '316_jumia.jpg',
#  192: '317_jumia.jpg',
#  193: '318_jumia.jpg',
#  194: '319_jumia.jpg',
#  195: '320_jumia.jpg',
#  196: '321_jumia.jpg',
#  197: '322_jumia.jpg',
#  198: '323_jumia.jpg',
#  199: '324_jumia.jpg',
#  200: '325_jumia.jpg',
#  201: '326_jumia.jpg',
#  202: '327_jumia.jpg',
#  203: '328_jumia.jpg',
#  204: '329_jumia.jpg',
#  205: '330_jumia.jpg',
#  206: '331_jumia.jpg',
#  207: '332_jumia.jpg',
#  208: '333_jumia.jpg',
#  209: '334_jumia.jpg',
#  210: '335_jumia.jpg',
#  211: '336_jumia.jpg',
#  212: '337_jumia.jpg',
#  213: '338_jumia.jpg',
#  214: '339_jumia.jpg',
#  215: '33_olist.jpg',
#  216: '340_jumia.jpg',
#  217: '341_jumia.jpg',
#  218: '342_jumia.jpg',
#  219: '343_jumia.jpg',
#  220: '344_jumia.jpg',
#  221: '345_jumia.jpg',
#  222: '346_jumia.jpg',
#  223: '347_jumia.jpg',
#  224: '348_jumia.jpg',
#  225: '349_jumia.jpg',
#  226: '34_olist.jpg',
#  227: '350_jumia.jpg',
#  228: '351_jumia.jpg',
#  229: '352_jumia.jpg',
#  230: '353_jumia.jpg',
#  231: '354_jumia.jpg',
#  232: '355_jumia.jpg',
#  233: '356_jumia.jpg',
#  234: '357_jumia.jpg',
#  235: '358_jumia.jpg',
#  236: '359_jumia.jpg',
#  237: '360_jumia.jpg',
#  238: '361_jumia.jpg',
#  239: '362_jumia.jpg',
#  240: '363_jumia.jpg',
#  241: '364_jumia.jpg',
#  242: '365_jumia.jpg',
#  243: '366_jumia.jpg',
#  244: '367_jumia.jpg',
#  245: '368_jumia.jpg',
#  246: '369_jumia.jpg',
#  247: '36_olist.jpg',
#  248: '370_jumia.jpg',
#  249: '371_jumia.jpg',
#  250: '372_jumia.jpg',
#  251: '373_jumia.jpg',
#  252: '374_jumia.jpg',
#  253: '375_jumia.jpg',
#  254: '376_jumia.jpg',
#  255: '377_jumia.jpg',
#  256: '378_jumia.jpg',
#  257: '379_jumia.jpg',
#  258: '37_olist.jpg',
#  259: '380_jumia.jpg',
#  260: '381_jumia.jpg',
#  261: '382_jumia.jpg',
#  262: '383_jumia.jpg',
#  263: '384_jumia.jpg',
#  264: '385_jumia.jpg',
#  265: '386_jumia.jpg',
#  266: '387_jumia.jpg',
#  267: '388_jumia.jpg',
#  268: '389_jumia.jpg',
#  269: '38_olist.jpg',
#  270: '390_jumia.jpg',
#  271: '391_jumia.jpg',
#  272: '392_jumia.jpg',
#  273: '393_jumia.jpg',
#  274: '394_jumia.jpg',
#  275: '395_jumia.jpg',
#  276: '396_jumia.jpg',
#  277: '397_jumia.jpg',
#  278: '398_jumia.jpg',
#  279: '399_jumia.jpg',
#  280: '39_olist.jpg',
#  281: '400_jumia.jpg',
#  282: '401_jumia.jpg',
#  283: '402_jumia.jpg',
#  284: '403_jumia.jpg',
#  285: '404_jumia.jpg',
#  286: '405_jumia.jpg',
#  287: '406_jumia.jpg',
#  288: '407_jumia.jpg',
#  289: '408_jumia.jpg',
#  290: '409_jumia.jpg',
#  291: '40_olist.jpg',
#  292: '410_jumia.jpg',
#  293: '411_jumia.jpg',
#  294: '412_jumia.jpg',
#  295: '413_jumia.jpg',
#  296: '414_jumia.jpg',
#  297: '415_jumia.jpg',
#  298: '416_jumia.jpg',
#  299: '417_jumia.jpg',
#  300: '418_jumia.jpg',
#  301: '419_jumia.jpg',
#  302: '41_ebay.jpg',
#  303: '420_jumia.jpg',
#  304: '421_jumia.jpg',
#  305: '422_jumia.jpg',
#  306: '423_jumia.jpg',
#  307: '424_jumia.jpg',
#  308: '425_jumia.jpg',
#  309: '426_jumia.jpg',
#  310: '427_jumia.jpg',
#  311: '428_jumia.jpg',
#  312: '429_jumia.jpg',
#  313: '42_ebay.jpg',
#  314: '430_jumia.jpg',
#  315: '431_jumia.jpg',
#  316: '432_jumia.jpg',
#  317: '433_jumia.jpg',
#  318: '434_jumia.jpg',
#  319: '435_jumia.jpg',
#  320: '436_jumia.jpg',
#  321: '437_jumia.jpg',
#  322: '438_jumia.jpg',
#  323: '439_jumia.jpg',
#  324: '43_ebay.jpg',
#  325: '440_jumia.jpg',
#  326: '441_jumia.jpg',
#  327: '442_jumia.jpg',
#  328: '443_jumia.jpg',
#  329: '444_jumia.jpg',
#  330: '445_jumia.jpg',
#  331: '446_jumia.jpg',
#  332: '447_jumia.jpg',
#  333: '448_jumia.jpg',
#  334: '449_jumia.jpg',
#  335: '44_ebay.jpg',
#  336: '450_jumia.jpg',
#  337: '451_jumia.jpg',
#  338: '452_jumia.jpg',
#  339: '453_jumia.jpg',
#  340: '454_jumia.jpg',
#  341: '455_jumia.jpg',
#  342: '456_jumia.jpg',
#  343: '457_jumia.jpg',
#  344: '458_jumia.jpg',
#  345: '459_jumia.jpg',
#  346: '45_ebay.jpg',
#  347: '460_jumia.jpg',
#  348: '461_jumia.jpg',
#  349: '462_jumia.jpg',
#  350: '463_jumia.jpg',
#  351: '464_jumia.jpg',
#  352: '465_jumia.jpg',
#  353: '466_jumia.jpg',
#  354: '467_jumia.jpg',
#  355: '468_jumia.jpg',
#  356: '469_jumia.jpg',
#  357: '46_ebay.jpg',
#  358: '470_jumia.jpg',
#  359: '471_jumia.jpg',
#  360: '472_jumia.jpg',
#  361: '473_jumia.jpg',
#  362: '474_jumia.jpg',
#  363: '475_jumia.jpg',
#  364: '476_jumia.jpg',
#  365: '477_jumia.jpg',
#  366: '478_jumia.jpg',
#  367: '479_jumia.jpg',
#  368: '47_ebay.jpg',
#  369: '480_jumia.jpg',
#  370: '481_jumia.jpg',
#  371: '482_jumia.jpg',
#  372: '483_jumia.jpg',
#  373: '484_jumia.jpg',
#  374: '485_jumia.jpg',
#  375: '486_jumia.jpg',
#  376: '487_jumia.jpg',
#  377: '488_jumia.jpg',
#  378: '489_jumia.jpg',
#  379: '48_ebay.jpg',
#  380: '490_jumia.jpg',
#  381: '491_jumia.jpg',
#  382: '492_jumia.jpg',
#  383: '493_jumia.jpg',
#  384: '494_jumia.jpg',
#  385: '495_jumia.jpg',
#  386: '496_jumia.jpg',
#  387: '497_jumia.jpg',
#  388: '498_jumia.jpg',
#  389: '499_jumia.jpg',
#  390: '49_ebay.jpg',
#  391: '500_jumia.jpg',
#  392: '501_jumia.jpg',
#  393: '502_jumia.jpg',
#  394: '503_jumia.jpg',
#  395: '504_jumia.jpg',
#  396: '505_jumia.jpg',
#  397: '506_jumia.jpg',
#  398: '507_jumia.jpg',
#  399: '508_jumia.jpg',
#  400: '509_jumia.jpg',
#  401: '50_ebay.jpg',
#  402: '510_jumia.jpg',
#  403: '511_jumia.jpg',
#  404: '512_jumia.jpg',
#  405: '513_jumia.jpg',
#  406: '514_jumia.jpg',
#  407: '515_jumia.jpg',
#  408: '516_jumia.jpg',
#  409: '517_jumia.jpg',
#  410: '518_jumia.jpg',
#  411: '519_jumia.jpg',
#  412: '51_ebay.jpg',
#  413: '520_jumia.jpg',
#  414: '521_jumia.jpg',
#  415: '522_jumia.jpg',
#  416: '523_jumia.jpg',
#  417: '524_jumia.jpg',
#  418: '525_jumia.jpg',
#  419: '526_jumia.jpg',
#  420: '527_jumia.jpg',
#  421: '528_jumia.jpg',
#  422: '529_jumia.jpg',
#  423: '52_ebay.jpg',
#  424: '530_jumia.jpg',
#  425: '531_jumia.jpg',
#  426: '532_jumia.jpg',
#  427: '533_jumia.jpg',
#  428: '534_jumia.jpg',
#  429: '535_jumia.jpg',
#  430: '536_jumia.jpg',
#  431: '537_jumia.jpg',
#  432: '538_jumia.jpg',
#  433: '539_jumia.jpg',
#  434: '540_jumia.jpg',
#  435: '541_jumia.jpg',
#  436: '542_jumia.jpg',
#  437: '543_jumia.jpg',
#  438: '544_jumia.jpg',
#  439: '545_jumia.jpg',
#  440: '546_jumia.jpg',
#  441: '547_jumia.jpg',
#  442: '548_jumia.jpg',
#  443: '549_jumia.jpg',
#  444: '54_ebay.jpg',
#  445: '550_jumia.jpg',
#  446: '551_jumia.jpg',
#  447: '552_jumia.jpg',
#  448: '553_jumia.jpg',
#  449: '554_jumia.jpg',
#  450: '555_jumia.jpg',
#  451: '556_jumia.jpg',
#  452: '557_jumia.jpg',
#  453: '558_jumia.jpg',
#  454: '559_jumia.jpg',
#  455: '55_ebay.jpg',
#  456: '560_jumia.jpg',
#  457: '561_jumia.jpg',
#  458: '562_jumia.jpg',
#  459: '563_jumia.jpg',
#  460: '564_jumia.jpg',
#  461: '565_jumia.jpg',
#  462: '566_jumia.jpg',
#  463: '567_jumia.jpg',
#  464: '568_jumia.jpg',
#  465: '569_jumia.jpg',
#  466: '56_ebay.jpg',
#  467: '570_jumia.jpg',
#  468: '571_jumia.jpg',
#  469: '572_jumia.jpg',
#  470: '573_jumia.jpg',
#  471: '574_jumia.jpg',
#  472: '575_jumia.jpg',
#  473: '576_jumia.jpg',
#  474: '577_jumia.jpg',
#  475: '578_jumia.jpg',
#  476: '579_jumia.jpg',
#  477: '580_jumia.jpg',
#  478: '581_jumia.jpg',
#  479: '582_jumia.jpg',
#  480: '583_jumia.jpg',
#  481: '584_jumia.jpg',
#  482: '585_jumia.jpg',
#  483: '586_jumia.jpg',
#  484: '587_jumia.jpg',
#  485: '588_jumia.jpg',
#  486: '589_jumia.jpg',
#  487: '58_ebay.jpg',
#  488: '590_jumia.jpg',
#  489: '591_jumia.jpg',
#  490: '592_jumia.jpg',
#  491: '593_jumia.jpg',
#  492: '594_jumia.jpg',
#  493: '595_jumia.jpg',
#  494: '596_jumia.jpg',
#  495: '597_jumia.jpg',
#  496: '598_jumia.jpg',
#  497: '599_jumia.jpg',
#  498: '59_ebay.jpg',
#  499: '5_olist.jpg',
#  500: '600_jumia.jpg',
#  501: '601_jumia.jpg',
#  502: '602_jumia.jpg',
#  503: '603_jumia.jpg',
#  504: '604_jumia.jpg',
#  505: '605_jumia.jpg',
#  506: '606_jumia.jpg',
#  507: '607_jumia.jpg',
#  508: '608_jumia.jpg',
#  509: '609_jumia.jpg',
#  510: '60_ebay.jpg',
#  511: '610_jumia.jpg',
#  512: '611_jumia.jpg',
#  513: '612_jumia.jpg',
#  514: '613_jumia.jpg',
#  515: '614_jumia.jpg',
#  516: '615_jumia.jpg',
#  517: '616_jumia.jpg',
#  518: '617_jumia.jpg',
#  519: '618_jumia.jpg',
#  520: '619_jumia.jpg',
#  521: '61_ebay.jpg',
#  522: '620_jumia.jpg',
#  523: '621_jumia.jpg',
#  524: '622_jumia.jpg',
#  525: '623_jumia.jpg',
#  526: '624_jumia.jpg',
#  527: '625_jumia.jpg',
#  528: '626_jumia.jpg',
#  529: '627_jumia.jpg',
#  530: '628_jumia.jpg',
#  531: '629_jumia.jpg',
#  532: '630_jumia.jpg',
#  533: '631_jumia.jpg',
#  534: '632_jumia.jpg',
#  535: '633_jumia.jpg',
#  536: '634_jumia.jpg',
#  537: '635_jumia.jpg',
#  538: '636_jumia.jpg',
#  539: '637_jumia.jpg',
#  540: '638_jumia.jpg',
#  541: '639_jumia.jpg',
#  542: '63_jumia.jpg',
#  543: '640_jumia.jpg',
#  544: '641_jumia.jpg',
#  545: '642_jumia.jpg',
#  546: '643_jumia.jpg',
#  547: '644_jumia.jpg',
#  548: '645_jumia.jpg',
#  549: '646_jumia.jpg',
#  550: '647_jumia.jpg',
#  551: '648_jumia.jpg',
#  552: '649_jumia.jpg',
#  553: '64_jumia.jpg',
#  554: '650_jumia.jpg',
#  555: '651_jumia.jpg',
#  556: '652_jumia.jpg',
#  557: '653_jumia.jpg',
#  558: '654_jumia.jpg',
#  559: '656_jumia.jpg',
#  560: '658_jumia.jpg',
#  561: '659_jumia.jpg',
#  562: '65_jumia.jpg',
#  563: '660_jumia.jpg',
#  564: '661_jumia.jpg',
#  565: '662_jumia.jpg',
#  566: '663_jumia.jpg',
#  567: '664_jumia.jpg',
#  568: '665_jumia.jpg',
#  569: '666_jumia.jpg',
#  570: '668_jumia.jpg',
#  571: '669_jumia.jpg',
#  572: '66_jumia.jpg',
#  573: '672_jumia.jpg',
#  574: '673_jumia.jpg',
#  575: '674_jumia.jpg',
#  576: '675_jumia.jpg',
#  577: '676_jumia.jpg',
#  578: '677_jumia.jpg',
#  579: '678_jumia.jpg',
#  580: '679_jumia.jpg',
#  581: '67_jumia.jpg',
#  582: '680_jumia.jpg',
#  583: '681_jumia.jpg',
#  584: '682_jumia.jpg',
#  585: '683_jumia.jpg',
#  586: '684_jumia.jpg',
#  587: '685_jumia.jpg',
#  588: '686_jumia.jpg',
#  589: '687_jumia.jpg',
#  590: '688_jumia.jpg',
#  591: '689_jumia.jpg',
#  592: '68_jumia.jpg',
#  593: '690_jumia.jpg',
#  594: '691_jumia.jpg',
#  595: '692_jumia.jpg',
#  596: '693_jumia.jpg',
#  597: '694_jumia.jpg',
#  598: '695_jumia.jpg',
#  599: '696_jumia.jpg',
#  600: '697_jumia.jpg',
#  601: '698_jumia.jpg',
#  602: '699_jumia.jpg',
#  603: '69_jumia.jpg',
#  604: '6_olist.jpg',
#  605: '700_jumia.jpg',
#  606: '701_jumia.jpg',
#  607: '702_jumia.jpg',
#  608: '703_jumia.jpg',
#  609: '704_jumia.jpg',
#  610: '705_jumia.jpg',
#  611: '706_jumia.jpg',
#  612: '707_jumia.jpg',
#  613: '708_jumia.jpg',
#  614: '709_jumia.jpg',
#  615: '70_jumia.jpg',
#  616: '710_jumia.jpg',
#  617: '711_jumia.jpg',
#  618: '712_jumia.jpg',
#  619: '713_jumia.jpg',
#  620: '714_jumia.jpg',
#  621: '715_jumia.jpg',
#  622: '716_jumia.jpg',
#  623: '717_jumia.jpg',
#  624: '718_jumia.jpg',
#  625: '719_jumia.jpg',
#  626: '71_jumia.jpg',
#  627: '720_jumia.jpg',
#  628: '721_jumia.jpg',
#  629: '722_jumia.jpg',
#  630: '723_ebay.jpg',
#  631: '724_ebay.jpg',
#  632: '725_ebay.jpg',
#  633: '726_ebay.jpg',
#  634: '727_ebay.jpg',
#  635: '728_ebay.jpg',
#  636: '729_ebay.jpg',
#  637: '72_jumia.jpg',
#  638: '730_ebay.jpg',
#  639: '731_ebay.jpg',
#  640: '732_ebay.jpg',
#  641: '733_ebay.jpg',
#  642: '734_ebay.jpg',
#  643: '735_ebay.jpg',
#  644: '736_ebay.jpg',
#  645: '737_ebay.jpg',
#  646: '738_ebay.jpg',
#  647: '739_ebay.jpg',
#  648: '73_jumia.jpg',
#  649: '740_ebay.jpg',
#  650: '741_ebay.jpg',
#  651: '742_ebay.jpg',
#  652: '743_ebay.jpg',
#  653: '744_ebay.jpg',
#  654: '745_ebay.jpg',
#  655: '746_ebay.jpg',
#  656: '747_ebay.jpg',
#  657: '748_ebay.jpg',
#  658: '749_ebay.jpg',
#  659: '74_jumia.jpg',
#  660: '750_ebay.jpg',
#  661: '751_ebay.jpg',
#  662: '752_ebay.jpg',
#  663: '753_ebay.jpg',
#  664: '754_ebay.jpg',
#  665: '755_ebay.jpg',
#  666: '756_ebay.jpg',
#  667: '757_ebay.jpg',
#  668: '758_ebay.jpg',
#  669: '759_ebay.jpg',
#  670: '75_jumia.jpg',
#  671: '760_ebay.jpg',
#  672: '761_ebay.jpg',
#  673: '762_ebay.jpg',
#  674: '763_ebay.jpg',
#  675: '764_ebay.jpg',
#  676: '765_ebay.jpg',
#  677: '766_ebay.jpg',
#  678: '767_ebay.jpg',
#  679: '768_ebay.jpg',
#  680: '769_ebay.jpg',
#  681: '76_jumia.jpg',
#  682: '770_ebay.jpg',
#  683: '771_ebay.jpg',
#  684: '772_ebay.jpg',
#  685: '773_ebay.jpg',
#  686: '774_ebay.jpg',
#  687: '775_ebay.jpg',
#  688: '776_ebay.jpg',
#  689: '777_ebay.jpg',
#  690: '778_ebay.jpg',
#  691: '779_ebay.jpg',
#  692: '77_jumia.jpg',
#  693: '780_ebay.jpg',
#  694: '781_ebay.jpg',
#  695: '782_ebay.jpg',
#  696: '783_ebay.jpg',
#  697: '784_ebay.jpg',
#  698: '785_ebay.jpg',
#  699: '786_ebay.jpg',
#  700: '787_ebay.jpg',
#  701: '788_ebay.jpg',
#  702: '789_ebay.jpg',
#  703: '78_jumia.jpg',
#  704: '790_ebay.jpg',
#  705: '791_ebay.jpg',
#  706: '792_ebay.jpg',
#  707: '793_ebay.jpg',
#  708: '794_ebay.jpg',
#  709: '795_ebay.jpg',
#  710: '796_ebay.jpg',
#  711: '797_ebay.jpg',
#  712: '798_ebay.jpg',
#  713: '799_ebay.jpg',
#  714: '79_jumia.jpg',
#  715: '7_olist.jpg',
#  716: '800_ebay.jpg',
#  717: '801_ebay.jpg',
#  718: '802_ebay.jpg',
#  719: '803_ebay.jpg',
#  720: '804_ebay.jpg',
#  721: '805_ebay.jpg',
#  722: '806_ebay.jpg',
#  723: '807_ebay.jpg',
#  724: '808_ebay.jpg',
#  725: '809_ebay.jpg',
#  726: '80_jumia.jpg',
#  727: '810_ebay.jpg',
#  728: '811_ebay.jpg',
#  729: '812_ebay.jpg',
#  730: '813_ebay.jpg',
#  731: '814_ebay.jpg',
#  732: '815_ebay.jpg',
#  733: '816_ebay.jpg',
#  734: '817_ebay.jpg',
#  735: '818_ebay.jpg',
#  736: '819_ebay.jpg',
#  737: '81_jumia.jpg',
#  738: '820_ebay.jpg',
#  739: '821_ebay.jpg',
#  740: '822_ebay.jpg',
#  741: '823_ebay.jpg',
#  742: '824_ebay.jpg',
#  743: '825_ebay.jpg',
#  744: '826_ebay.jpg',
#  745: '827_ebay.jpg',
#  746: '828_ebay.jpg',
#  747: '829_ebay.jpg',
#  748: '82_jumia.jpg',
#  749: '830_ebay.jpg',
#  750: '831_ebay.jpg',
#  751: '832_ebay.jpg',
#  752: '833_ebay.jpg',
#  753: '834_ebay.jpg',
#  754: '835_ebay.jpg',
#  755: '836_ebay.jpg',
#  756: '837_ebay.jpg',
#  757: '838_ebay.jpg',
#  758: '839_ebay.jpg',
#  759: '83_jumia.jpg',
#  760: '840_ebay.jpg',
#  761: '841_ebay.jpg',
#  762: '842_ebay.jpg',
#  763: '843_ebay.jpg',
#  764: '844_ebay.jpg',
#  765: '845_ebay.jpg',
#  766: '846_ebay.jpg',
#  767: '847_ebay.jpg',
#  768: '848_ebay.jpg',
#  769: '849_ebay.jpg',
#  770: '84_jumia.jpg',
#  771: '850_ebay.jpg',
#  772: '851_ebay.jpg',
#  773: '852_ebay.jpg',
#  774: '853_jumia.jpg',
#  775: '854_jumia.jpg',
#  776: '855_jumia.jpg',
#  777: '856_jumia.jpg',
#  778: '857_jumia.jpg',
#  779: '858_jumia.jpg',
#  780: '859_jumia.jpg',
#  781: '85_jumia.jpg',
#  782: '860_jumia.jpg',
#  783: '861_jumia.jpg',
#  784: '862_jumia.jpg',
#  785: '863_jumia.jpg',
#  786: '864_jumia.jpg',
#  787: '865_jumia.jpg',
#  788: '866_jumia.jpg',
#  789: '867_jumia.jpg',
#  790: '868_jumia.jpg',
#  791: '869_jumia.jpg',
#  792: '86_jumia.jpg',
#  793: '871_jumia.jpg',
#  794: '872_jumia.jpg',
#  795: '873_jumia.jpg',
#  796: '874_jumia.jpg',
#  797: '875_jumia.jpg',
#  798: '876_jumia.jpg',
#  799: '877_jumia.jpg',
#  800: '878_jumia.jpg',
#  801: '879_jumia.jpg',
#  802: '87_jumia.jpg',
#  803: '880_jumia.jpg',
#  804: '881_jumia.jpg',
#  805: '882_jumia.jpg',
#  806: '883_jumia.jpg',
#  807: '884_jumia.jpg',
#  808: '885_jumia.jpg',
#  809: '886_jumia.jpg',
#  810: '887_jumia.jpg',
#  811: '889_jumia.jpg',
#  812: '88_jumia.jpg',
#  813: '890_jumia.jpg',
#  814: '891_jumia.jpg',
#  815: '892_jumia.jpg',
#  816: '893_jumia.jpg',
#  817: '894_jumia.jpg',
#  818: '895_jumia.jpg',
#  819: '896_jumia.jpg',
#  820: '897_jumia.jpg',
#  821: '898_jumia.jpg',
#  822: '899_jumia.jpg',
#  823: '89_jumia.jpg',
#  824: '900_jumia.jpg',
#  825: '901_jumia.jpg',
#  826: '902_jumia.jpg',
#  827: '903_jumia.jpg',
#  828: '904_jumia.jpg',
#  829: '905_jumia.jpg',
#  830: '906_jumia.jpg',
#  831: '907_jumia.jpg',
#  832: '908_jumia.jpg',
#  833: '909_jumia.jpg',
#  834: '90_jumia.jpg',
#  835: '910_jumia.jpg',
#  836: '911_jumia.jpg',
#  837: '912_jumia.jpg',
#  838: '913_jumia.jpg',
#  839: '914_jumia.jpg',
#  840: '915_jumia.jpg',
#  841: '916_jumia.jpg',
#  842: '917_jumia.jpg',
#  843: '918_jumia.jpg',
#  844: '919_jumia.jpg',
#  845: '91_jumia.jpg',
#  846: '920_jumia.jpg',
#  847: '921_jumia.jpg',
#  848: '922_jumia.jpg',
#  849: '923_jumia.jpg',
#  850: '924_jumia.jpg',
#  851: '925_jumia.jpg',
#  852: '926_jumia.jpg',
#  853: '927_jumia.jpg',
#  854: '928_jumia.jpg',
#  855: '929_jumia.jpg',
#  856: '92_jumia.jpg',
#  857: '930_jumia.jpg',
#  858: '931_jumia.jpg',
#  859: '932_jumia.jpg',
#  860: '933_jumia.jpg',
#  861: '934_jumia.jpg',
#  862: '935_jumia.jpg',
#  863: '936_jumia.jpg',
#  864: '937_jumia.jpg',
#  865: '938_jumia.jpg',
#  866: '939_jumia.jpg',
#  867: '93_jumia.jpg',
#  868: '940_jumia.jpg',
#  869: '941_jumia.jpg',
#  870: '942_jumia.jpg',
#  871: '943_jumia.jpg',
#  872: '944_jumia.jpg',
#  873: '945_jumia.jpg',
#  874: '946_jumia.jpg',
#  875: '947_jumia.jpg',
#  876: '948_jumia.jpg',
#  877: '949_jumia.jpg',
#  878: '94_jumia.jpg',
#  879: '950_jumia.jpg',
#  880: '951_jumia.jpg',
#  881: '952_jumia.jpg',
#  882: '953_jumia.jpg',
#  883: '954_jumia.jpg',
#  884: '955_jumia.jpg',
#  885: '956_jumia.jpg',
#  886: '957_jumia.jpg',
#  887: '958_jumia.jpg',
#  888: '959_jumia.jpg',
#  889: '95_jumia.jpg',
#  890: '960_jumia.jpg',
#  891: '961_jumia.jpg',
#  892: '962_jumia.jpg',
#  893: '963_jumia.jpg',
#  894: '964_jumia.jpg',
#  895: '965_jumia.jpg',
#  896: '966_jumia.jpg',
#  897: '967_jumia.jpg',
#  898: '968_jumia.jpg',
#  899: '969_jumia.jpg',
#  900: '96_jumia.jpg',
#  901: '970_jumia.jpg',
#  902: '971_jumia.jpg',
#  903: '972_jumia.jpg',
#  904: '97_jumia.jpg',
#  905: '98_jumia.jpg',
#  906: '99_jumia.jpg',
#  907: '9_olist.jpg'}

# %%
figure, ax = plt.subplots(len(out_come), 2, figsize =(20,10) )

for i, out in enumerate(out_come):
    
    imge = mpimg.imread(file_index[out])
    ax.ravel()[i].imshow(imge)
    ax.ravel()[i].set_title(f"image {i}")
    ax.ravel()[i].set_axis_off()

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
